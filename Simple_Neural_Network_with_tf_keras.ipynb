# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/machinelearning147/MachineLearning-YouTube/blob/master/Simple_Neural_Network_with_tf_keras.ipynb)

# %% [markdown]
# # Tensorflow + Keras + Colaboratory = deep learning made easy
# ![alt text](https://cdn-images-1.medium.com/max/634/1*-r7EkRUvzkqDyyr2kwdeDg.png)
#
# ![alt text](https://lh3.googleusercontent.com/jKDpJZTAVMEBtbvn69tvnckMASk6RnMBjD07oCr3D1j9j3SSu2WPXKAcWWs=w530-h278-p-rw)
#
# [tf.keras docs](https://t.co/LAGOoR5EqI)
#
#
# ---

# %% [markdown]
# **import required packages**

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

# %% [markdown]
# **load and preprocess data**

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# 11501568/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# **define your model**

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %% [markdown]
# **compile the model with specifying optimizer, loos and metrics**

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# **train the model**

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 10s 163us/step - loss: 0.2238 - acc: 0.9334
# Epoch 2/5
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0974 - acc: 0.9701
# Epoch 3/5
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.0692 - acc: 0.9784
# Epoch 4/5
#    32/60000 [..............................] - ETA: 17s - loss: 0.0125 - acc: 1.0000
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.0523 - acc: 0.9835
# Epoch 5/5
# 60000/60000 [==============================] - 9s 148us/step - loss: 0.0462 - acc: 0.9847

# %% [markdown]
# **evaluate the model on test data**

# %%
loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 0s 43us/step

# %%
print("loss: {} accuracy: {}".format(loss, accuracy))
# Out:
# loss: 0.0645322566157 accuracy: 0.9804
