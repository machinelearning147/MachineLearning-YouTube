# %% [markdown]
# # Image, Audio and Video within Jupyter Notebook

# %%
# import required packages
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# ## displaying an Image

# %%
img_path = '../etc/Machine Learning.jpg'
Image(img_path, width=1200, height=300)

# %% [markdown]
# ## playing audio from local

# %%
# get the audio file
audio_link = '../etc/GuitarD4.wav'

# %%
# play using Audio
Audio(data=audio_link, autoplay=False)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## playing video from YouTube

# %%
id = '1909b7QEZQY'
YouTubeVideo(id=id, width=900, height=400)
