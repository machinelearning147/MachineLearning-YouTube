# %% [markdown]
# <a href="https://colab.research.google.com/github/machinelearning147/MachineLearning-YouTube/blob/master/1_openCV_read_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import required packages**

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %% [markdown]
# **read image**

# %%
# Load an color image in grayscale
img = cv.imread('sherman.jpg',0)

# %% [markdown]
# **show image**

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# **Load a color image and show**

# %%
# Load an color image in color
img = cv.imread('sherman.jpg',1)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# **BGR to RGB Conversion**

# %%
# Load an color image in color
img = cv.imread('sherman.jpg',1)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img, interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# Ref:
#
# 1. https://docs.opencv.org/master/dc/d2e/tutorial_py_image_display.html
# 2. https://stackoverflow.com/questions/50963283/python-opencv-imshow-doesnt-need-convert-from-bgr-to-rgb
